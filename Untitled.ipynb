# %%
from tools import analysistools as atools
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
df = atools.xyzaToDataframe('/Volumes/LaCie/clus/rebuilds/244606_-1_0_out.xyza')

# %%
atools.plotRotationTrajectoryOnSphere(atools.getRotationData(df))
plt.show()
# Out:
# [0.  0.  6.5] [ 3.45448 -1.43812  7.91364]
