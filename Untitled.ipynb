# %%
from tools import analysistools as atools
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import random
import os

# %%
dfs = map(lambda x: os.path.join('/Volumes/LaCie/clus/rebuilds',x),filter(lambda x: 'out.csv' in x, os.listdir('/Volumes/LaCie/clus/rebuilds')))

# %%
s = random.sample(dfs,1)[-1]
print s
# Out:
# /Volumes/LaCie/clus/rebuilds/245246_14000_0_out.csv

# %%
df = pd.read_csv(s)

# %%
fig = plt.figure(figsize=(13, 13))
atools.plotRotationTrajectoryOnSphere(atools.getRotationData(df),fig)
plt.show()
